# %% [markdown]
# <a href="https://colab.research.google.com/github/MamatJasseh/PROJECTS/blob/main/BAN230_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Series**

# %%
X = pd.Series([10, 20, 30, 40])
X
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
X[1]
# Out:
# 20

# %%
X[[1, 2, 3]]
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
X[1:4]
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
X = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
X
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
X.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
X.values
# Out:
# array([10, 20, 30, 40])

# %%
X
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
X1 = X.reindex(['b', 'c', 'd', 'e', 'f'])
X1
# Out:
# b    20.0
# c    30.0
# d    40.0
# e     NaN
# f     NaN
# dtype: float64

# %%
X
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
X['a':'c']
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
X
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
X1 = X.reindex(['b', 'c', 'd'])
X1
# Out:
# b    20
# c    30
# d    40
# dtype: int64

# %%
X
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
X["a":"c"]
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
X[0:3]
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
list(np.arange(3))
# Out:
# [0, 1, 2]

# %%
list(np.arange(6))
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
ser = pd.Series(np.arange(3))
ser
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
# ser[-1]

# %%
ser.iloc[-1]
# Out:
# 2

# %%
ser.iloc[-2]
# Out:
# 1

# %% [markdown]
# **Filter**

# %%
X
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
X[X>20] = 99
X
# Out:
# a    10
# b    20
# c    99
# d    99
# dtype: int64

# %%
X['c':'d'] = 199
X
# Out:
# a     10
# b     20
# c    199
# d    199
# dtype: int64

# %%
X = pd.Series([10, -10, 20, -20, 30, -30, 40, -40])
X
# Out:
# 0    10
# 1   -10
# 2    20
# 3   -20
# 4    30
# 5   -30
# 6    40
# 7   -40
# dtype: int64

# %%
X < 0
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
X[X < 0]
# Out:
# 1   -10
# 3   -20
# 5   -30
# 7   -40
# dtype: int64

# %%
X[X < -10]
# Out:
# 3   -20
# 5   -30
# 7   -40
# dtype: int64

# %% [markdown]
# **Mathematical operations**

# %%
X1 = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
X2 = pd.Series([20, 30, 40, 50], index=['b', 'c', 'd', 'e'])
X1 + X2
# Out:
# a     NaN
# b    40.0
# c    60.0
# d    80.0
# e     NaN
# dtype: float64

# %%
X1 + X1
# Out:
# a    20
# b    40
# c    60
# d    80
# dtype: int64

# %%
X1 * X2
# Out:
# a       NaN
# b     400.0
# c     900.0
# d    1600.0
# e       NaN
# dtype: float64

# %% [markdown]
# **Series creation with dictionary**

# %%
D = {'a': 10, 'b': 20, 'c': 30, 'd': 40}
X = pd.Series(D)
X
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
X = pd.Series(D, index=['d', 'c', 'b', 'a'])
X
# Out:
# d    40
# c    30
# b    20
# a    10
# dtype: int64

# %%
X = pd.Series(D, index=['d', 'c', 'b', 'a', 'e'])
X
# Out:
# d    40.0
# c    30.0
# b    20.0
# a    10.0
# e     NaN
# dtype: float64

# %%
X.isnull()
# Out:
# d    False
# c    False
# b    False
# a    False
# e     True
# dtype: bool

# %%
X.notnull()
# Out:
# d     True
# c     True
# b     True
# a     True
# e    False
# dtype: bool

# %% [markdown]
# ## **Dataframe**

# %%
D = {"State": ['AP', 'HP', 'UP', 'KA'],
     "Size": [10, 20, 30, 40],
     "Year": [2001, 2002, 2003, 2004]
     }

X = pd.DataFrame(D)
X
# Out:
#   State  Size  Year
# 0    AP    10  2001
# 1    HP    20  2002
# 2    UP    30  2003
# 3    KA    40  2004

# %%
df = pd.DataFrame(D, columns=['State', 'Size'])
df
# Out:
#   State  Size
# 0    AP    10
# 1    HP    20
# 2    UP    30
# 3    KA    40

# %%
df = pd.DataFrame(D, columns=['Year', 'State', 'Size'])
df
# Out:
#    Year State  Size
# 0  2001    AP    10
# 1  2002    HP    20
# 2  2003    UP    30
# 3  2004    KA    40

# %%
df = pd.DataFrame(D, columns=['Year', 'State', 'Size', 'Population'])
df
# Out:
#    Year State  Size Population
# 0  2001    AP    10        NaN
# 1  2002    HP    20        NaN
# 2  2003    UP    30        NaN
# 3  2004    KA    40        NaN

# %%
df['Year']
# Out:
# 0    2001
# 1    2002
# 2    2003
# 3    2004
# Name: Year, dtype: int64

# %%
df.Year
# Out:
# 0    2001
# 1    2002
# 2    2003
# 3    2004
# Name: Year, dtype: int64

# %%
df[['Year', 'State']]
# Out:
#    Year State
# 0  2001    AP
# 1  2002    HP
# 2  2003    UP
# 3  2004    KA

# %%
df
# Out:
#    Year State  Size Population
# 0  2001    AP    10        NaN
# 1  2002    HP    20        NaN
# 2  2003    UP    30        NaN
# 3  2004    KA    40        NaN

# %%
df.columns
# Out:
# Index(['Year', 'State', 'Size', 'Population'], dtype='object')

# %%
df['Population'] = 10
df
# Out:
#    Year State  Size  Population
# 0  2001    AP    10          10
# 1  2002    HP    20          10
# 2  2003    UP    30          10
# 3  2004    KA    40          10

# %%
df['Population'] = [10, 100, 1000, 10000]
df
# Out:
#    Year State  Size  Population
# 0  2001    AP    10          10
# 1  2002    HP    20         100
# 2  2003    UP    30        1000
# 3  2004    KA    40       10000

# %%
D
# Out:
# {'State': ['AP', 'HP', 'UP', 'KA'],
#  'Size': [10, 20, 30, 40],
#  'Year': [2001, 2002, 2003, 2004]}

# %%
df = pd.DataFrame(D, columns=['Year', 'State', 'Size', 'Population'])

# %%
df
# Out:
#    Year State  Size Population
# 0  2001    AP    10        NaN
# 1  2002    HP    20        NaN
# 2  2003    UP    30        NaN
# 3  2004    KA    40        NaN

# %%
df['Size>20'] = df['Size'] > 20
df
# Out:
#    Year State  Size Population  Size>20
# 0  2001    AP    10        NaN    False
# 1  2002    HP    20        NaN    False
# 2  2003    UP    30        NaN     True
# 3  2004    KA    40        NaN     True

# %%
df = pd.DataFrame(D, columns=['Year', 'State', 'Size', 'Population'],
                  index=['a', 'b', 'c', 'd'])

df
# Out:
#    Year State  Size Population
# a  2001    AP    10        NaN
# b  2002    HP    20        NaN
# c  2003    UP    30        NaN
# d  2004    KA    40        NaN

# %%
Pop = pd.Series([100, 200, 300, 400], index=['a', 'b', 'c', 'd'])
Pop
# Out:
# a    100
# b    200
# c    300
# d    400
# dtype: int64

# %%
df['Population'] = Pop
df
# Out:
#    Year State  Size  Population
# a  2001    AP    10         100
# b  2002    HP    20         200
# c  2003    UP    30         300
# d  2004    KA    40         400

# %%
df.transpose()
# Out:
#                a     b     c     d
# Year        2001  2002  2003  2004
# State         AP    HP    UP    KA
# Size          10    20    30    40
# Population   100   200   300   400

# %%
df.T
# Out:
#                a     b     c     d
# Year        2001  2002  2003  2004
# State         AP    HP    UP    KA
# Size          10    20    30    40
# Population   100   200   300   400

# %%
df
# Out:
#    Year State  Size  Population
# a  2001    AP    10         100
# b  2002    HP    20         200
# c  2003    UP    30         300
# d  2004    KA    40         400

# %%
del df['Population']
df
# Out:
#    Year State  Size
# a  2001    AP    10
# b  2002    HP    20
# c  2003    UP    30
# d  2004    KA    40

# %%
df = pd.DataFrame(D, columns=['Year', 'State', 'Size', 'Population'],
                  index=['a', 'b', 'c', 'd'])

df
# Out:
#    Year State  Size Population
# a  2001    AP    10        NaN
# b  2002    HP    20        NaN
# c  2003    UP    30        NaN
# d  2004    KA    40        NaN

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['Year', 'State', 'Size', 'Population'], dtype='object')

# %%
df1 = df.reindex(['b', 'c', 'd', 'e', 'f'])
df1
# Out:
#      Year State  Size Population
# b  2002.0    HP  20.0        NaN
# c  2003.0    UP  30.0        NaN
# d  2004.0    KA  40.0        NaN
# e     NaN   NaN   NaN        NaN
# f     NaN   NaN   NaN        NaN

# %%
df
# Out:
#    Year State  Size Population
# a  2001    AP    10        NaN
# b  2002    HP    20        NaN
# c  2003    UP    30        NaN
# d  2004    KA    40        NaN

# %%
df1 = df.reindex(columns=['Year', 'Size', 'Col1', 'Col2'])
df1
# Out:
#    Year  Size  Col1  Col2
# a  2001    10   NaN   NaN
# b  2002    20   NaN   NaN
# c  2003    30   NaN   NaN
# d  2004    40   NaN   NaN

# %%
df
# Out:
#    Year State  Size Population
# a  2001    AP    10        NaN
# b  2002    HP    20        NaN
# c  2003    UP    30        NaN
# d  2004    KA    40        NaN

# %%
df.drop('a')
# Out:
#    Year State  Size Population
# b  2002    HP    20        NaN
# c  2003    UP    30        NaN
# d  2004    KA    40        NaN

# %%
df
# Out:
#    Year State  Size Population
# a  2001    AP    10        NaN
# b  2002    HP    20        NaN
# c  2003    UP    30        NaN
# d  2004    KA    40        NaN

# %%
df.drop(['a', 'b'])
# Out:
#    Year State  Size Population
# c  2003    UP    30        NaN
# d  2004    KA    40        NaN

# %%
df
# Out:
#    Year State  Size Population
# a  2001    AP    10        NaN
# b  2002    HP    20        NaN
# c  2003    UP    30        NaN
# d  2004    KA    40        NaN

# %%
df.drop(columns=['Year', 'State'])
# Out:
#    Size Population
# a    10        NaN
# b    20        NaN
# c    30        NaN
# d    40        NaN

# %%
df
# Out:
#    Year State  Size Population
# a  2001    AP    10        NaN
# b  2002    HP    20        NaN
# c  2003    UP    30        NaN
# d  2004    KA    40        NaN

# %%
df.drop(columns=['Year', 'State'], inplace=True)
df
# Out:
#    Size Population
# a    10        NaN
# b    20        NaN
# c    30        NaN
# d    40        NaN

# %%
df = pd.DataFrame(np.arange(15).reshape(5,3),
                  index=['a', 'b', 'c', 'd', 'e'],
                  columns=['Col1', 'Col2', 'Col3'])
df
# Out:
#    Col1  Col2  Col3
# a     0     1     2
# b     3     4     5
# c     6     7     8
# d     9    10    11
# e    12    13    14

# %%
df['Col1']
# Out:
# a     0
# b     3
# c     6
# d     9
# e    12
# Name: Col1, dtype: int64

# %%
df.loc['a']
# Out:
# Col1    0
# Col2    1
# Col3    2
# Name: a, dtype: int64

# %%
df.iloc[0]
# Out:
# Col1    0
# Col2    1
# Col3    2
# Name: a, dtype: int64

# %%
df.loc['a':'c', 'Col1': 'Col2']
# Out:
#    Col1  Col2
# a     0     1
# b     3     4
# c     6     7

# %%
df.iloc[0:3, 0:2]
# Out:
#    Col1  Col2
# a     0     1
# b     3     4
# c     6     7

# %%
df.loc[['a', 'c'], ['Col1', 'Col2']]
# Out:
#    Col1  Col2
# a     0     1
# c     6     7

# %%
df.iloc[[0, 2], [0, 1]]
# Out:
#    Col1  Col2
# a     0     1
# c     6     7

# %%
df
# Out:
#    Col1  Col2  Col3
# a     0     1     2
# b     3     4     5
# c     6     7     8
# d     9    10    11
# e    12    13    14

# %%
df[df['Col3']>5]
# Out:
#    Col1  Col2  Col3
# c     6     7     8
# d     9    10    11
# e    12    13    14

# %%
df[df>4]
# Out:
#    Col1  Col2  Col3
# a   NaN   NaN   NaN
# b   NaN   NaN   5.0
# c   6.0   7.0   8.0
# d   9.0  10.0  11.0
# e  12.0  13.0  14.0

# %%
df
# Out:
#    Col1  Col2  Col3
# a     0     1     2
# b     3     4     5
# c     6     7     8
# d     9    10    11
# e    12    13    14

# %% [markdown]
# **Sorting**

# %%
df = pd.DataFrame([[50, 3, 30],
                  [100, 3, 300],
                  [40, 30, 40],
                  [30, 30, 5]],
                 index=['b', 'a', 'c', 'd'],
                 columns=['col2', 'col1', 'col3'])
df
# Out:
#    col2  col1  col3
# b    50     3    30
# a   100     3   300
# c    40    30    40
# d    30    30     5

# %%
df.sort_index()
# Out:
#    col2  col1  col3
# a   100     3   300
# b    50     3    30
# c    40    30    40
# d    30    30     5

# %%
df
# Out:
#    col2  col1  col3
# b    50     3    30
# a   100     3   300
# c    40    30    40
# d    30    30     5

# %%
df.sort_index(axis=1)
# Out:
#    col1  col2  col3
# b     3    50    30
# a     3   100   300
# c    30    40    40
# d    30    30     5

# %%
df.sort_index().sort_index(axis=1)
# Out:
#    col1  col2  col3
# a     3   100   300
# b     3    50    30
# c    30    40    40
# d    30    30     5

# %%
df
# Out:
#    col2  col1  col3
# b    50     3    30
# a   100     3   300
# c    40    30    40
# d    30    30     5

# %%
df.sort_values(by='col2')
# Out:
#    col2  col1  col3
# d    30    30     5
# c    40    30    40
# b    50     3    30
# a   100     3   300

# %%
df
# Out:
#    col2  col1  col3
# b    50     3    30
# a   100     3   300
# c    40    30    40
# d    30    30     5

# %%
df.sort_values(by=['col1', 'col3'])
# Out:
#    col2  col1  col3
# b    50     3    30
# a   100     3   300
# d    30    30     5
# c    40    30    40

# %%
df = pd.DataFrame(np.random.rand(8, 5), columns=['a', 'b', 'c', 'd', 'e'])
df
# Out:
#           a         b         c         d         e
# 0  0.215854  0.843518  0.040102  0.588453  0.866558
# 1  0.300309  0.745478  0.895377  0.452403  0.859168
# 2  0.977404  0.251147  0.639493  0.986806  0.138482
# 3  0.104300  0.094504  0.315612  0.872613  0.841401
# 4  0.962458  0.342108  0.098781  0.666934  0.377922
# 5  0.935670  0.930819  0.952496  0.205955  0.077017
# 6  0.758509  0.474283  0.839933  0.925569  0.319103
# 7  0.609828  0.938264  0.554706  0.664602  0.839766

# %%
df.describe()
# Out:
#               a         b         c         d         e
# count  8.000000  8.000000  8.000000  8.000000  8.000000
# mean   0.608041  0.577515  0.542063  0.670417  0.539927
# std    0.357429  0.329463  0.356853  0.260797  0.346378
# min    0.104300  0.094504  0.040102  0.205955  0.077017
# 25%    0.279195  0.319368  0.261404  0.554440  0.273948
# 50%    0.684168  0.609881  0.597099  0.665768  0.608844
# 75%    0.942367  0.865344  0.853794  0.885852  0.845843
# max    0.977404  0.938264  0.952496  0.986806  0.866558

# %%
df.mean()
# Out:
# a    0.608041
# b    0.577515
# c    0.542063
# d    0.670417
# e    0.539927
# dtype: float64

# %%
df.sum()
# Out:
# a    4.864331
# b    4.620122
# c    4.336500
# d    5.363336
# e    4.319416
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 0    0.510897
# 1    0.650547
# 2    0.598666
# 3    0.445686
# 4    0.489641
# 5    0.620391
# 6    0.663479
# 7    0.721433
# dtype: float64

# %%
df.sum(axis=1)
# Out:
# 0    2.554485
# 1    3.252735
# 2    2.993331
# 3    2.228431
# 4    2.448204
# 5    3.101957
# 6    3.317397
# 7    3.607166
# dtype: float64

# %%
df.corr()
# Out:
#           a         b         c         d         e
# a  1.000000 -0.019185  0.291652 -0.001197 -0.886477
# b -0.019185  1.000000  0.275303 -0.749935  0.164566
# c  0.291652  0.275303  1.000000 -0.251747 -0.391463
# d -0.001197 -0.749935 -0.251747  1.000000 -0.007821
# e -0.886477  0.164566 -0.391463 -0.007821  1.000000

# %%
df['a'].corr(df['b'])
# Out:
# -0.019184795787093402

# %% [markdown]
# **Data Storage with CSV**

# %%
df = pd.read_csv("/content/drive/MyDrive/bCR-PythonForData-Series2/sample1.csv")
df
# Out:
#     10  20   30   40  XYZ
# 0   10  40   50   60  XYZ
# 1  100  20  130  140  DEF

# %%
df = pd.read_csv("/content/drive/MyDrive/bCR-PythonForData-Series2/sample1.csv",
                 header=None)
df
# Out:
#      0   1    2    3    4
# 0   10  20   30   40  XYZ
# 1   10  40   50   60  XYZ
# 2  100  20  130  140  DEF

# %%
df = pd.read_csv("/content/drive/MyDrive/bCR-PythonForData-Series2/sample1.csv",
                 header=None,
                 names=['a', 'b', 'c', 'd', 'e'])
df
# Out:
#      a   b    c    d    e
# 0   10  20   30   40  XYZ
# 1   10  40   50   60  XYZ
# 2  100  20  130  140  DEF

# %%
df = pd.read_csv("/content/drive/MyDrive/bCR-PythonForData-Series2/sample1.csv",
                 names=['a', 'b', 'c', 'd', 'e'])
df
# Out:
#      a   b    c    d    e
# 0   10  20   30   40  XYZ
# 1   10  40   50   60  XYZ
# 2  100  20  130  140  DEF

# %%
df = pd.read_csv("/content/drive/MyDrive/bCR-PythonForData-Series2/sample1.csv",
                 names=['a', 'b', 'c', 'd', 'e'],
                 index_col=['e'])
df
# Out:
#        a   b    c    d
# e
# XYZ   10  20   30   40
# XYZ   10  40   50   60
# DEF  100  20  130  140

# %%
df = pd.read_csv("/content/drive/MyDrive/bCR-PythonForData-Series2/sample2.csv")
df
# Out:
#     Col1  Col2  Col3   Col4 Col5 Col6
# 0     10  20.0    30   30.0    f    d
# 1     30  40.0    50   60.0    b    d
# 2    100  20.0   130  140.0    c    d
# 3    110  40.0   170  186.0   a     d
# 4    155  40.0   220  241.0    b    e
# 5    192   NaN   270  295.8    c    e
# 6    229  48.0   320    NaN   a     d
# 7    266  52.0   370  405.4    b    e
# 8    303  56.0   420  460.2    c    f
# 9    340   NaN   470    NaN   a     f
# 10   377  64.0   520  569.8    b    f
# 11   414  68.0   570  624.6    c    f

# %%
df.isnull()
# Out:
#      Col1   Col2   Col3   Col4   Col5   Col6
# 0   False  False  False  False  False  False
# 1   False  False  False  False  False  False
# 2   False  False  False  False  False  False
# 3   False  False  False  False  False  False
# 4   False  False  False  False  False  False
# 5   False   True  False  False  False  False
# 6   False  False  False   True  False  False
# 7   False  False  False  False  False  False
# 8   False  False  False  False  False  False
# 9   False   True  False   True  False  False
# 10  False  False  False  False  False  False
# 11  False  False  False  False  False  False

# %%
df.isnull().any()
# Out:
# Col1    False
# Col2     True
# Col3    False
# Col4     True
# Col5    False
# Col6    False
# dtype: bool

# %%
df
# Out:
#     Col1  Col2  Col3   Col4 Col5 Col6
# 0     10  20.0    30   30.0    f    d
# 1     30  40.0    50   60.0    b    d
# 2    100  20.0   130  140.0    c    d
# 3    110  40.0   170  186.0   a     d
# 4    155  40.0   220  241.0    b    e
# 5    192   NaN   270  295.8    c    e
# 6    229  48.0   320    NaN   a     d
# 7    266  52.0   370  405.4    b    e
# 8    303  56.0   420  460.2    c    f
# 9    340   NaN   470    NaN   a     f
# 10   377  64.0   520  569.8    b    f
# 11   414  68.0   570  624.6    c    f

# %%
df = pd.read_csv("/content/drive/MyDrive/bCR-PythonForData-Series2/sample2.csv",
                 na_values=['f'])
df
# Out:
#     Col1  Col2  Col3   Col4 Col5 Col6
# 0     10  20.0    30   30.0  NaN    d
# 1     30  40.0    50   60.0    b    d
# 2    100  20.0   130  140.0    c    d
# 3    110  40.0   170  186.0   a     d
# 4    155  40.0   220  241.0    b    e
# 5    192   NaN   270  295.8    c    e
# 6    229  48.0   320    NaN   a     d
# 7    266  52.0   370  405.4    b    e
# 8    303  56.0   420  460.2    c  NaN
# 9    340   NaN   470    NaN   a   NaN
# 10   377  64.0   520  569.8    b  NaN
# 11   414  68.0   570  624.6    c  NaN
